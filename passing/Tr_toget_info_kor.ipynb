# %%
import pandas as pd
import numpy as np
import requests

# %%
def cr_df(number = 2):
    # list_1
    df_save = []
    recent_date = ['2020-12-31']
    df_save.append(pd.DataFrame(recent_date, columns=['date']))
    # list_2
    params = []
    for i in range(number):
        params.append({
            'access_key': '21ab33d30ae3b6ebcb1e5727a699f17d',
            'symbols' : '015710.XKRX',
            'date_to' : df_save[i]['date'].tail(1)
        })
        api_result = requests.get(f'https://api.marketstack.com/v1/tickers/eod', params[i])
        api_response = api_result.json()
        df_save.append(pd.DataFrame(api_response['data']['eod']))
    return pd.concat(df_save).drop(index=0).reset_index().drop_duplicates("date", keep="first")

# %%
import requests

params = {
    'access_key': '21ab33d30ae3b6ebcb1e5727a699f17d',
    "symbols": "HWG.XLON"}

api_result = requests.get('https://api.marketstack.com/v1/eod', params)
api_response = api_result.json()
api_response
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 100, 'total': 6822},
#  'data': [{'open': 117.0,
#    'high': 118.36,
#    'low': 115.5,
#    'close': 117.0,
#    'volume': 9673.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 117.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-02-26T00:00:00+0000'},
#   {'open': 119.5,
#    'high': 119.75,
#    'low': 116.3588,
#    'close': 119.5,
#    'volume': 115007.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 119.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-02-25T00:00:00+0000'},
#   {'open': 117.0,
#    'high': 118.5,
#    'low': 115.45,
#    'close': 118.0,
#    'volume': 96397.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 118.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-02-24T00:00:00+0000'},
#   {'open': 115.5,
#    'high': 119.0,
#    'low': 115.5,
#    'close': 116.0,
#    'volume': 115885.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 116.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-02-23T00:00:00+0000'},
#   {'open': 114.0,
#    'high': 119.5,
#    'low': 113.0,
#    'close': 116.5,
#    'volume': 112967.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 116.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-02-22T00:00:00+0000'},
#   {'open': 113.5,
#    'high': 116.1049,
#    'low': 113.5,
#    'close': 113.5,
#    'volume': 33163.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 113.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-02-19T00:00:00+0000'},
#   {'open': 115.0,
#    'high': 117.0,
#    'low': 115.0,
#    'close': 117.0,
#    'volume': 19445.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 117.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-02-18T00:00:00+0000'},
#   {'open': 113.5,
#    'high': 118.0,
#    'low': 113.033,
#    'close': 115.0,
#    'volume': 123787.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 115.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-02-17T00:00:00+0000'},
#   {'open': 113.0,
#    'high': 116.0,
#    'low': 112.5376,
#    'close': 114.5,
#    'volume': 43449.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 114.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-02-16T00:00:00+0000'},
#   {'open': 119.5,
#    'high': 119.5,
#    'low': 113.325,
#    'close': 119.0,
#    'volume': 34747.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 119.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-02-15T00:00:00+0000'},
#   {'open': 119.0,
#    'high': 119.5,
#    'low': 113.35,
#    'close': 114.5,
#    'volume': 36818.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 114.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-02-12T00:00:00+0000'},
#   {'open': 116.0,
#    'high': 120.0,
#    'low': 112.5,
#    'close': 116.0,
#    'volume': 82892.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 116.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-02-11T00:00:00+0000'},
#   {'open': 114.5,
#    'high': 117.0,
#    'low': 114.5,
#    'close': 117.0,
#    'volume': 11807.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 117.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-02-10T00:00:00+0000'},
#   {'open': 113.0,
#    'high': 117.0,
#    'low': 113.0,
#    'close': 114.75,
#    'volume': 57949.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 114.75,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-02-09T00:00:00+0000'},
#   {'open': 119.5,
#    'high': 119.5,
#    'low': 113.0,
#    'close': 113.0,
#    'volume': 62922.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 113.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-02-08T00:00:00+0000'},
#   {'open': 118.5,
#    'high': 118.54,
#    'low': 115.0001,
#    'close': 118.0,
#    'volume': 98259.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 118.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-02-05T00:00:00+0000'},
#   {'open': 120.0,
#    'high': 120.0,
#    'low': 116.5,
#    'close': 119.0,
#    'volume': 56902.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 119.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-02-04T00:00:00+0000'},
#   {'open': 117.5,
#    'high': 119.5,
#    'low': 112.5,
#    'close': 112.5,
#    'volume': 98559.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 112.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-02-03T00:00:00+0000'},
#   {'open': 117.5,
#    'high': 118.98,
#    'low': 116.5,
#    'close': 116.5,
#    'volume': 41039.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 116.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-02-02T00:00:00+0000'},
#   {'open': 122.5,
#    'high': 122.5,
#    'low': 115.45,
#    'close': 116.0,
#    'volume': 83149.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 116.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-02-01T00:00:00+0000'},
#   {'open': 119.5,
#    'high': 119.5,
#    'low': 117.5,
#    'close': 117.5,
#    'volume': 137662.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 117.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-01-29T00:00:00+0000'},
#   {'open': 121.0,
#    'high': 122.0,
#    'low': 118.0,
#    'close': 119.25,
#    'volume': 341541.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 119.25,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-01-28T00:00:00+0000'},
#   {'open': 117.5,
#    'high': 122.0,
#    'low': 117.5,
#    'close': 121.5,
#    'volume': 2437213.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 121.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-01-27T00:00:00+0000'},
#   {'open': 108.0,
#    'high': 121.898,
#    'low': 108.0,
#    'close': 121.0,
#    'volume': 637948.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 121.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-01-26T00:00:00+0000'},
#   {'open': 107.5,
#    'high': 107.5,
#    'low': 105.49,
#    'close': 107.5,
#    'volume': 88081.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 107.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-01-25T00:00:00+0000'},
#   {'open': 107.0,
#    'high': 107.5,
#    'low': 105.0,
#    'close': 106.5,
#    'volume': 29347.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 106.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-01-22T00:00:00+0000'},
#   {'open': 107.0,
#    'high': 107.0,
#    'low': 105.28,
#    'close': 107.0,
#    'volume': 34470.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 107.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-01-21T00:00:00+0000'},
#   {'open': 107.5,
#    'high': 108.3,
#    'low': 105.273,
#    'close': 107.5,
#    'volume': 3184694.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 107.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-01-20T00:00:00+0000'},
#   {'open': 107.5,
#    'high': 107.5,
#    'low': 105.13,
#    'close': 107.0,
#    'volume': 94971.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 107.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-01-19T00:00:00+0000'},
#   {'open': 107.5,
#    'high': 107.5,
#    'low': 105.13,
#    'close': 106.5,
#    'volume': 11321.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 106.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-01-18T00:00:00+0000'},
#   {'open': 107.0,
#    'high': 108.5,
#    'low': 104.9751,
#    'close': 107.5,
#    'volume': 78771.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 107.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-01-15T00:00:00+0000'},
#   {'open': 104.5,
#    'high': 106.66,
#    'low': 104.5,
#    'close': 104.5,
#    'volume': 34275.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 104.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-01-14T00:00:00+0000'},
#   {'open': 105.5,
#    'high': 106.5,
#    'low': 103.776,
#    'close': 106.5,
#    'volume': 472165.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 106.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-01-13T00:00:00+0000'},
#   {'open': 104.5,
#    'high': 105.391,
#    'low': 101.57,
#    'close': 105.0,
#    'volume': 262506.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 105.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-01-12T00:00:00+0000'},
#   {'open': 102.5,
#    'high': 105.875,
#    'low': 101.0,
#    'close': 101.0,
#    'volume': 26222.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 101.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-01-11T00:00:00+0000'},
#   {'open': 107.0,
#    'high': 107.0,
#    'low': 102.0,
#    'close': 104.0,
#    'volume': 143418.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 104.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-01-08T00:00:00+0000'},
#   {'open': 102.0,
#    'high': 104.4,
#    'low': 101.22,
#    'close': 102.0,
#    'volume': 69912.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 102.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-01-07T00:00:00+0000'},
#   {'open': 102.5,
#    'high': 104.6,
#    'low': 100.0,
#    'close': 102.5,
#    'volume': 93298.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 102.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-01-06T00:00:00+0000'},
#   {'open': 101.5,
#    'high': 104.607,
#    'low': 101.5,
#    'close': 101.5,
#    'volume': 17023.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 101.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-01-05T00:00:00+0000'},
#   {'open': 104.5,
#    'high': 108.0,
#    'low': 101.5,
#    'close': 102.5,
#    'volume': 115275.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 102.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2021-01-04T00:00:00+0000'},
#   {'open': 106.0,
#    'high': 107.1,
#    'low': 102.0,
#    'close': 105.0,
#    'volume': 28115.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 105.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-12-31T00:00:00+0000'},
#   {'open': 106.5,
#    'high': 108.0,
#    'low': 103.0,
#    'close': 108.0,
#    'volume': 38840.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 108.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-12-30T00:00:00+0000'},
#   {'open': 104.5,
#    'high': 109.5,
#    'low': 101.5,
#    'close': 102.5,
#    'volume': 199867.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 102.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-12-29T00:00:00+0000'},
#   {'open': 102.0,
#    'high': 104.5,
#    'low': 101.45,
#    'close': 104.5,
#    'volume': 146600.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 104.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-12-24T00:00:00+0000'},
#   {'open': 104.5,
#    'high': 104.5,
#    'low': 99.365,
#    'close': 104.5,
#    'volume': 113059.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 104.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-12-23T00:00:00+0000'},
#   {'open': 100.0,
#    'high': 102.832,
#    'low': 99.79,
#    'close': 101.5,
#    'volume': 81545.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 101.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-12-22T00:00:00+0000'},
#   {'open': 104.5,
#    'high': 104.5,
#    'low': 97.0,
#    'close': 97.0,
#    'volume': 165904.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 97.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-12-21T00:00:00+0000'},
#   {'open': 104.0,
#    'high': 104.0,
#    'low': 99.0,
#    'close': 100.0,
#    'volume': 114215.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 100.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-12-18T00:00:00+0000'},
#   {'open': 98.8,
#    'high': 103.0,
#    'low': 98.208,
#    'close': 100.5,
#    'volume': 341740.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 100.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-12-17T00:00:00+0000'},
#   {'open': 98.0,
#    'high': 99.79,
#    'low': 98.0,
#    'close': 99.0,
#    'volume': 90031.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 99.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-12-16T00:00:00+0000'},
#   {'open': 100.0,
#    'high': 100.0,
#    'low': 98.0,
#    'close': 98.0,
#    'volume': 75492.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 98.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-12-15T00:00:00+0000'},
#   {'open': 100.0,
#    'high': 100.0,
#    'low': 98.053,
#    'close': 100.0,
#    'volume': 63142.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 100.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-12-14T00:00:00+0000'},
#   {'open': 100.0,
#    'high': 100.3575,
#    'low': 98.0,
#    'close': 100.0,
#    'volume': 117236.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 100.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-12-11T00:00:00+0000'},
#   {'open': 102.0,
#    'high': 103.14,
#    'low': 98.93,
#    'close': 100.0,
#    'volume': 220130.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 100.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-12-10T00:00:00+0000'},
#   {'open': 104.0,
#    'high': 105.0,
#    'low': 100.5,
#    'close': 100.5,
#    'volume': 299115.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 100.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-12-09T00:00:00+0000'},
#   {'open': 104.0,
#    'high': 105.005,
#    'low': 103.0,
#    'close': 103.0,
#    'volume': 29839.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 103.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-12-08T00:00:00+0000'},
#   {'open': 105.0,
#    'high': 107.5,
#    'low': 103.0,
#    'close': 103.0,
#    'volume': 65201.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 103.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-12-07T00:00:00+0000'},
#   {'open': 108.0,
#    'high': 108.0,
#    'low': 104.16,
#    'close': 105.0,
#    'volume': 93224.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 105.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-12-04T00:00:00+0000'},
#   {'open': 104.5,
#    'high': 106.5,
#    'low': 104.0,
#    'close': 105.0,
#    'volume': 62376.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 105.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-12-03T00:00:00+0000'},
#   {'open': 104.5,
#    'high': 105.61,
#    'low': 102.5,
#    'close': 102.5,
#    'volume': 69588.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 102.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-12-02T00:00:00+0000'},
#   {'open': 105.0,
#    'high': 106.0,
#    'low': 102.0,
#    'close': 106.0,
#    'volume': 60493.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 106.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-12-01T00:00:00+0000'},
#   {'open': 106.5,
#    'high': 107.1,
#    'low': 104.0,
#    'close': 104.0,
#    'volume': 79776.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 104.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-11-30T00:00:00+0000'},
#   {'open': 105.5,
#    'high': 106.235,
#    'low': 103.5,
#    'close': 104.5,
#    'volume': 74961.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 104.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-11-27T00:00:00+0000'},
#   {'open': 106.5,
#    'high': 107.0,
#    'low': 104.91,
#    'close': 105.0,
#    'volume': 111896.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 105.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-11-26T00:00:00+0000'},
#   {'open': 106.0,
#    'high': 108.5,
#    'low': 104.0,
#    'close': 105.0,
#    'volume': 85783.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 105.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-11-25T00:00:00+0000'},
#   {'open': 104.5,
#    'high': 104.5,
#    'low': 103.41,
#    'close': 104.5,
#    'volume': 34868.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 104.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-11-24T00:00:00+0000'},
#   {'open': 105.0,
#    'high': 105.258,
#    'low': 102.5,
#    'close': 104.5,
#    'volume': 96305.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 104.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-11-23T00:00:00+0000'},
#   {'open': 105.5,
#    'high': 105.5,
#    'low': 101.5,
#    'close': 105.0,
#    'volume': 36416.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 105.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-11-20T00:00:00+0000'},
#   {'open': 103.5,
#    'high': 104.79,
#    'low': 101.5,
#    'close': 101.5,
#    'volume': 122802.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 101.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-11-19T00:00:00+0000'},
#   {'open': 106.0,
#    'high': 106.0,
#    'low': 102.22,
#    'close': 103.5,
#    'volume': 61760.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 103.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-11-18T00:00:00+0000'},
#   {'open': 104.5,
#    'high': 105.5,
#    'low': 102.0,
#    'close': 105.0,
#    'volume': 75470.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 105.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-11-17T00:00:00+0000'},
#   {'open': 104.5,
#    'high': 104.5,
#    'low': 100.0,
#    'close': 101.5,
#    'volume': 181629.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 101.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-11-16T00:00:00+0000'},
#   {'open': 101.5,
#    'high': 104.5,
#    'low': 100.5,
#    'close': 104.5,
#    'volume': 80533.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 104.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-11-13T00:00:00+0000'},
#   {'open': 100.5,
#    'high': 102.5,
#    'low': 100.0,
#    'close': 102.5,
#    'volume': 149255.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 102.5,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-11-12T00:00:00+0000'},
#   {'open': 99.4,
#    'high': 103.0,
#    'low': 95.0,
#    'close': 98.6,
#    'volume': 2324605.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 98.6,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-11-11T00:00:00+0000'},
#   {'open': 97.0,
#    'high': 99.0,
#    'low': 96.0,
#    'close': 96.6,
#    'volume': 929066.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 96.6,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-11-10T00:00:00+0000'},
#   {'open': 96.4,
#    'high': 99.6,
#    'low': 92.8,
#    'close': 97.6,
#    'volume': 294161.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 97.6,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-11-09T00:00:00+0000'},
#   {'open': 95.2,
#    'high': 96.4,
#    'low': 92.8,
#    'close': 96.4,
#    'volume': 119392.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 96.4,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-11-06T00:00:00+0000'},
#   {'open': 95.4,
#    'high': 95.4,
#    'low': 88.0,
#    'close': 95.4,
#    'volume': 58317.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 95.4,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-11-05T00:00:00+0000'},
#   {'open': 92.0,
#    'high': 95.0,
#    'low': 92.0,
#    'close': 92.0,
#    'volume': 70610.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 92.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-11-04T00:00:00+0000'},
#   {'open': 90.8,
#    'high': 94.4,
#    'low': 90.0,
#    'close': 90.0,
#    'volume': 86881.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 90.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-11-03T00:00:00+0000'},
#   {'open': 94.6,
#    'high': 94.6,
#    'low': 86.4,
#    'close': 86.8,
#    'volume': 148911.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 86.8,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-11-02T00:00:00+0000'},
#   {'open': 90.2,
#    'high': 92.55,
#    'low': 90.0,
#    'close': 90.8,
#    'volume': 10810.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 90.8,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-10-30T00:00:00+0000'},
#   {'open': 91.8,
#    'high': 93.8016,
#    'low': 88.0,
#    'close': 92.4,
#    'volume': 90143.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 92.4,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-10-29T00:00:00+0000'},
#   {'open': 90.0,
#    'high': 93.0,
#    'low': 90.0,
#    'close': 91.4,
#    'volume': 248049.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 91.4,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-10-28T00:00:00+0000'},
#   {'open': 90.2,
#    'high': 95.811,
#    'low': 90.2,
#    'close': 92.0,
#    'volume': 92076.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 92.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-10-27T00:00:00+0000'},
#   {'open': 97.6,
#    'high': 97.6,
#    'low': 90.676,
#    'close': 92.0,
#    'volume': 326759.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 92.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-10-26T00:00:00+0000'},
#   {'open': 91.2,
#    'high': 94.0,
#    'low': 90.6762,
#    'close': 94.0,
#    'volume': 3242183.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 94.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-10-23T00:00:00+0000'},
#   {'open': 93.0,
#    'high': 94.8669,
#    'low': 92.0544,
#    'close': 94.2,
#    'volume': 43705.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 94.2,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-10-22T00:00:00+0000'},
#   {'open': 94.8,
#    'high': 94.8,
#    'low': 90.992,
#    'close': 94.0,
#    'volume': 51907.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 94.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-10-21T00:00:00+0000'},
#   {'open': 94.0,
#    'high': 94.0,
#    'low': 92.0,
#    'close': 92.0,
#    'volume': 17848.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 92.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-10-20T00:00:00+0000'},
#   {'open': 94.0,
#    'high': 94.0,
#    'low': 91.388,
#    'close': 93.8,
#    'volume': 64393.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 93.8,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-10-19T00:00:00+0000'},
#   {'open': 90.2,
#    'high': 95.4199,
#    'low': 90.2,
#    'close': 93.4,
#    'volume': 37585.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 93.4,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-10-16T00:00:00+0000'},
#   {'open': 97.6,
#    'high': 97.6,
#    'low': 90.0,
#    'close': 92.0,
#    'volume': 130022.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 92.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-10-15T00:00:00+0000'},
#   {'open': 94.0,
#    'high': 94.0,
#    'low': 93.01,
#    'close': 93.8,
#    'volume': 191103.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 93.466,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-10-14T00:00:00+0000'},
#   {'open': 95.0,
#    'high': 95.0,
#    'low': 93.8,
#    'close': 94.0,
#    'volume': 848068.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 93.6653,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-10-13T00:00:00+0000'},
#   {'open': 93.6,
#    'high': 95.0,
#    'low': 92.0,
#    'close': 94.0,
#    'volume': 557967.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 94.0,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-10-12T00:00:00+0000'},
#   {'open': 94.8,
#    'high': 95.2,
#    'low': 93.2,
#    'close': 93.2,
#    'volume': 1978044.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 93.2,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-10-09T00:00:00+0000'},
#   {'open': 90.8,
#    'high': 96.6,
#    'low': 88.7606,
#    'close': 96.6,
#    'volume': 30365811.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 96.6,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-10-08T00:00:00+0000'},
#   {'open': 90.0,
#    'high': 90.0,
#    'low': 88.6,
#    'close': 89.4,
#    'volume': 423044.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 89.4,
#    'adj_open': None,
#    'adj_volume': None,
#    'symbol': 'HWG.XLON',
#    'exchange': 'XLON',
#    'date': '2020-10-07T00:00:00+0000'}]}

# %%
Sk_by_comp = []31
comp_list = ['012750.XKRX', '039010.XKRX']
for stock in range(2):
    Sk_by_comp.append(cr_df(comp_list[stock]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-6aa01d77da87> in <module>
#       2 comp_list = ['012750.XKRX', '039010.XKRX']
#       3 for stock in range(2):
# ----> 4     Sk_by_comp.append(cr_df(comp_list[stock]))
#
# <ipython-input-58-dcbb3fe64628> in cr_df(number)
#       6     # list_2
#       7     params = []
# ----> 8     for i in range(number):
#       9         params.append({
#      10             'access_key': '21ab33d30ae3b6ebcb1e5727a699f17d',
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
# 확인하고자 하는 해당 회사정보, index를 기입
Sk_by_comp[1]
# Out:
#      index                      date    open      high       low   close  \
# 0        1  2020-12-30T00:00:00+0000  135.58  135.9900  133.4000  133.72
# 1        2  2020-12-29T00:00:00+0000  138.05  138.7890  134.3409  134.87
# 2        3  2020-12-28T00:00:00+0000  133.99  137.3400  133.5100  136.69
# 3        4  2020-12-24T00:00:00+0000  131.32  133.4600  131.1000  131.97
# 4        5  2020-12-23T00:00:00+0000  132.16  132.4300  130.7800  130.96
# ..     ...                       ...     ...       ...       ...     ...
# 193     95  2020-03-26T00:00:00+0000  246.52  258.6800  246.3600  258.44
# 194     96  2020-03-25T00:00:00+0000  250.75  258.2500  244.3000  245.52
# 195     97  2020-03-24T00:00:00+0000  236.36  247.6900  234.3000  246.88
# 196     98  2020-03-23T00:00:00+0000  228.08  228.4997  212.6100  224.37
# 197     99  2020-03-20T00:00:00+0000  247.18  251.8300  228.0000  229.24
#
#           volume    adj_high     adj_low   adj_close    adj_open   adj_volume  \
# 0     96452124.0  135.990000  133.400000  133.720000  135.580000   96452124.0
# 1    121047324.0  138.789000  134.340900  134.870000  138.050000  121047324.0
# 2    123124632.0  137.340000  133.510000  136.690000  133.990000  123124632.0
# 3     54930064.0  133.460000  131.100000  131.970000  131.320000   54930064.0
# 4     88223692.0  132.430000  130.780000  130.960000  132.160000   88223692.0
# ..           ...         ...         ...         ...         ...          ...
# 193   63140169.0  257.997840  245.710329  257.758473  245.869907   63140169.0
# 194   75900510.0  257.568974  243.655761  244.872544  250.088752   75900510.0
# 195   71882773.0  247.036822  233.682132  246.228958  235.736700   71882773.0
# 196   84188208.0  227.897128  212.049330  223.778318  227.478535   84188208.0
# 197  100423346.0  251.165904  227.398746  228.635476  246.528167  100423346.0
#
#     symbol exchange
# 0     AAPL     XNAS
# 1     AAPL     XNAS
# 2     AAPL     XNAS
# 3     AAPL     XNAS
# 4     AAPL     XNAS
# ..     ...      ...
# 193   AAPL     XNAS
# 194   AAPL     XNAS
# 195   AAPL     XNAS
# 196   AAPL     XNAS
# 197   AAPL     XNAS
#
# [198 rows x 14 columns]

# %% [markdown]
# ----------------------------------------------------------------------------------------------
